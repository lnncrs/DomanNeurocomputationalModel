# %% [markdown]
# # Análise Exploratória
#
# Notebook para análise de dados de treinamento

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Adiciona src ao path
import sys
sys.path.append('../src')
